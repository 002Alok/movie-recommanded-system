# %% [markdown]
# <a href="https://colab.research.google.com/github/002Alok/movie-recommanded-system/blob/main/Train_model_on_ResNet50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.11/dist-packages (1.6.17)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.11/dist-packages (from kaggle) (1.17.0)
# Requirement already satisfied: certifi>=2023.7.22 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2025.1.31)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from kaggle) (4.67.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.11/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.3.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.11/dist-packages (from kaggle) (6.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.11/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->kaggle) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->kaggle) (3.10)

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle competitions download -c cifar-10
# Out:
# Downloading cifar-10.zip to /content
# 100% 714M/715M [00:24<00:00, 29.6MB/s]
# 100% 715M/715M [00:24<00:00, 31.0MB/s]

# %%
# !ls
# Out:
# cifar-10.zip  kaggle.json  sample_data

# %%
from zipfile import ZipFile
file_name = "cifar-10.zip"

with ZipFile(file_name, 'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
# !ls
# Out:
# cifar-10.zip  kaggle.json  sample_data	sampleSubmission.csv  test.7z  train.7z  trainLabels.csv

# %%
# !pip install py7zr
# Out:
# Collecting py7zr
#   Downloading py7zr-0.22.0-py3-none-any.whl.metadata (16 kB)
# Collecting texttable (from py7zr)
#   Downloading texttable-1.7.0-py2.py3-none-any.whl.metadata (9.8 kB)
# Collecting pycryptodomex>=3.16.0 (from py7zr)
#   Downloading pycryptodomex-3.22.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Collecting pyzstd>=0.15.9 (from py7zr)
#   Downloading pyzstd-0.16.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.4 kB)
# Collecting pyppmd<1.2.0,>=1.1.0 (from py7zr)
#   Downloading pyppmd-1.1.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Collecting pybcj<1.1.0,>=1.0.0 (from py7zr)
#   Downloading pybcj-1.0.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Collecting multivolumefile>=0.2.3 (from py7zr)
#   Downloading multivolumefile-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Collecting inflate64<1.1.0,>=1.0.0 (from py7zr)
#   Downloading inflate64-1.0.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting brotli>=1.1.0 (from py7zr)
#   Downloading Brotli-1.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from py7zr) (5.9.5)
# Downloading py7zr-0.22.0-py3-none-any.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.9/67.9 kB 3.2 MB/s eta 0:00:00
# Downloading Brotli-1.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 23.4 MB/s eta 0:00:00
# Downloading inflate64-1.0.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.2/96.2 kB 12.2 MB/s eta 0:00:00
# Downloading multivolumefile-0.2.3-py3-none-any.whl (17 kB)
# Downloading pybcj-1.0.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.6/50.6 kB 6.2 MB/s eta 0:00:00
# Downloading pycryptodomex-3.22.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 92.7 MB/s eta 0:00:00
# Downloading pyppmd-1.1.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.3/141.3 kB 17.8 MB/s eta 0:00:00
# Downloading pyzstd-0.16.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (413 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 413.7/413.7 kB 40.7 MB/s eta 0:00:00
# Downloading texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Installing collected packages: texttable, brotli, pyzstd, pyppmd, pycryptodomex, pybcj, multivolumefile, inflate64, py7zr
# Successfully installed brotli-1.1.0 inflate64-1.0.1 multivolumefile-0.2.3 py7zr-0.22.0 pybcj-1.0.3 pycryptodomex-3.22.0 pyppmd-1.1.1 pyzstd-0.16.2 texttable-1.7.0

# %%
import py7zr

archive=py7zr.SevenZipFile('train.7z', mode='r')
archive.extractall()
archive.close()
print('Done')
# Out:
# Done

# %%
import os
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from sklearn.model_selection import train_test_split

# %%
filename=os.listdir('train')

# %%
type(filename)
# Out:
# list

# %%
len(filename)
# Out:
# 50000

# %%
print(filename[0])
# Out:
# 7251.png

# %%
lables_df = pd.read_csv('/content/trainLabels.csv')

# %%
lables_df.shape
# Out:
# (50000, 2)

# %%
lables_df.head()
# Out:
#    id       label
# 0   1        frog
# 1   2       truck
# 2   3       truck
# 3   4        deer
# 4   5  automobile

# %%
lables_df.tail()
# Out:
#           id       label
# 49995  49996        bird
# 49996  49997        frog
# 49997  49998       truck
# 49998  49999  automobile
# 49999  50000  automobile

# %%
lables_df[lables_df['id']==7251]
# Out:
#         id label
# 7250  7251  frog

# %%
lables_df.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-9950de6b3704> in <cell line: 0>()
# ----> 1 lables_df.unique()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
lables_df['label'].unique()
# Out:
# array(['frog', 'truck', 'deer', 'automobile', 'bird', 'horse', 'ship',
#        'cat', 'dog', 'airplane'], dtype=object)

# %%
lables_df.count()
# Out:
# id       50000
# label    50000
# dtype: int64

# %%
lables_df['label'].value_counts()
# Out:
# label
# frog          5000
# truck         5000
# deer          5000
# automobile    5000
# bird          5000
# horse         5000
# ship          5000
# cat           5000
# dog           5000
# airplane      5000
# Name: count, dtype: int64

# %%
lables_dict={'airplane':0,'automobile':1,'bird':2,'cat':3,'deer':4,'dog':5,'frog':6,'horse':7,'ship':8,'truck':9}

# %%
lables_df['label'].apply(lambda x: lables_dict[x])
# Out:
# 0        6
# 1        9
# 2        9
# 3        4
# 4        1
#         ..
# 49995    2
# 49996    6
# 49997    9
# 49998    1
# 49999    1
# Name: label, Length: 50000, dtype: int64

# %%
label=lables_df['label'].apply(lambda x : lables_dict[x])

# %%
print(label)
# Out:
# 0        6
# 1        9
# 2        9
# 3        4
# 4        1
#         ..
# 49995    2
# 49996    6
# 49997    9
# 49998    1
# 49999    1
# Name: label, Length: 50000, dtype: int64

# %%
train_data_folder='/content/train/'
data=[]
id_list = lables_df['id']
for id in id_list:
  image = Image.open(train_data_folder+str(id)+'.png')
  image=np.array(image)
  data.append(image)

# %%
type(data)
# Out:
# list

# %%
len(data)
# Out:
# 50000

# %%
type(data[0])
# Out:
# numpy.ndarray

# %%
data[0].shape
# Out:
# (32, 32, 3)

# %%
x = np.array(data)
y = np.array(label)

# %%
print(x.shape)
print(y.shape)
# Out:
# (50000, 32, 32, 3)
# (50000,)

# %%
print(data[0])
# Out:
# [[[ 59  62  63]
#   [ 43  46  45]
#   [ 50  48  43]
#   ...
#   [158 132 108]
#   [152 125 102]
#   [148 124 103]]
#
#  [[ 16  20  20]
#   [  0   0   0]
#   [ 18   8   0]
#   ...
#   [123  88  55]
#   [119  83  50]
#   [122  87  57]]
#
#  [[ 25  24  21]
#   [ 16   7   0]
#   [ 49  27   8]
#   ...
#   [118  84  50]
#   [120  84  50]
#   [109  73  42]]
#
#  ...
#
#  [[208 170  96]
#   [201 153  34]
#   [198 161  26]
#   ...
#   [160 133  70]
#   [ 56  31   7]
#   [ 53  34  20]]
#
#  [[180 139  96]
#   [173 123  42]
#   [186 144  30]
#   ...
#   [184 148  94]
#   [ 97  62  34]
#   [ 83  53  34]]
#
#  [[177 144 116]
#   [168 129  94]
#   [179 142  87]
#   ...
#   [216 184 140]
#   [151 118  84]
#   [123  92  72]]]

# %%
print(x[0])
# Out:
# [[[ 59  62  63]
#   [ 43  46  45]
#   [ 50  48  43]
#   ...
#   [158 132 108]
#   [152 125 102]
#   [148 124 103]]
#
#  [[ 16  20  20]
#   [  0   0   0]
#   [ 18   8   0]
#   ...
#   [123  88  55]
#   [119  83  50]
#   [122  87  57]]
#
#  [[ 25  24  21]
#   [ 16   7   0]
#   [ 49  27   8]
#   ...
#   [118  84  50]
#   [120  84  50]
#   [109  73  42]]
#
#  ...
#
#  [[208 170  96]
#   [201 153  34]
#   [198 161  26]
#   ...
#   [160 133  70]
#   [ 56  31   7]
#   [ 53  34  20]]
#
#  [[180 139  96]
#   [173 123  42]
#   [186 144  30]
#   ...
#   [184 148  94]
#   [ 97  62  34]
#   [ 83  53  34]]
#
#  [[177 144 116]
#   [168 129  94]
#   [179 142  87]
#   ...
#   [216 184 140]
#   [151 118  84]
#   [123  92  72]]]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (40000, 32, 32, 3)
# (10000, 32, 32, 3)
# (40000,)
# (10000,)

# %%
print(x_train[0])
# Out:
# [[[34 36 43]
#   [37 37 51]
#   [44 44 64]
#   ...
#   [62 73 93]
#   [52 63 83]
#   [45 57 77]]
#
#  [[35 35 37]
#   [34 34 40]
#   [34 33 43]
#   ...
#   [58 69 89]
#   [50 60 80]
#   [47 58 78]]
#
#  [[34 33 35]
#   [33 32 36]
#   [33 32 38]
#   ...
#   [66 77 97]
#   [51 62 82]
#   [53 64 84]]
#
#  ...
#
#  [[32 32 38]
#   [32 31 37]
#   [33 33 38]
#   ...
#   [41 38 45]
#   [34 31 38]
#   [36 32 40]]
#
#  [[33 31 36]
#   [32 30 36]
#   [34 32 37]
#   ...
#   [37 35 40]
#   [32 29 35]
#   [30 28 33]]
#
#  [[37 32 35]
#   [37 32 36]
#   [37 33 36]
#   ...
#   [49 47 49]
#   [47 45 48]
#   [58 56 58]]]

# %%
x_test_scaled=x_test/255
x_train_scaled=x_train/255

# %%
_

# %% [markdown]
# Build Neural Network

# %%
import tensorflow as tf
from tensorflow import keras

# %%
from keras.models import Sequential
from keras.layers import Dense,Flatten,Conv2D,MaxPooling2D

# %%
no_of_classes=10

model = Sequential()
model.add(Conv2D(32,(3,3),activation='relu',input_shape=(32,32,3)))
model.add(MaxPooling2D((2,2)))
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Flatten())
model.add(Dense(64,activation='relu'))
model.add(Dense(32,activation='relu'))
model.add(Dense(no_of_classes,activation='softmax'))

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(x_train_scaled,y_train,validation_split=0.1,epochs=20)
# Out:
# Epoch 1/20
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8793 - loss: 0.3429 - val_accuracy: 0.6625 - val_loss: 1.3121
# Epoch 2/20
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8930 - loss: 0.3015 - val_accuracy: 0.6607 - val_loss: 1.3936
# Epoch 3/20
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9024 - loss: 0.2865 - val_accuracy: 0.6562 - val_loss: 1.4891
# Epoch 4/20
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9113 - loss: 0.2513 - val_accuracy: 0.6653 - val_loss: 1.5338
# Epoch 5/20
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9208 - loss: 0.2280 - val_accuracy: 0.6528 - val_loss: 1.6623
# Epoch 6/20
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9258 - loss: 0.2096 - val_accuracy: 0.6510 - val_loss: 1.6878
# Epoch 7/20
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9320 - loss: 0.1923 - val_accuracy: 0.6522 - val_loss: 1.8222
# Epoch 8/20
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9363 - loss: 0.1779 - val_accuracy: 0.6540 - val_loss: 1.9409
# Epoch 9/20
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9389 - loss: 0.1735 - val_accuracy: 0.6513 - val_loss: 1.9497
# Epoch 10/20
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9466 - loss: 0.1522 - val_accuracy: 0.6500 - val_loss: 2.0734
# Epoch 11/20
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9481 - loss: 0.1461 - val_accuracy: 0.6495 - val_loss: 2.0922
# Epoch 12/20
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9521 - loss: 0.1378 - val_accuracy: 0.6610 - val_loss: 2.1433
# Epoch 13/20
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9533 - loss: 0.1272 - val_accuracy: 0.6442 - val_loss: 2.2399
# Epoch 14/20
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9553 - loss: 0.1273 - val_accuracy: 0.6478 - val_loss: 2.3306
# Epoch 15/20
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9588 - loss: 0.1138 - val_accuracy: 0.6525 - val_loss: 2.3718
# Epoch 16/20
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9646 - loss: 0.1038 - val_accuracy: 0.6568 - val_loss: 2.5114
# Epoch 17/20
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9626 - loss: 0.1077 - val_accuracy: 0.6467 - val_loss: 2.5784
# Epoch 18/20
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9548 - loss: 0.1284 - val_accuracy: 0.6500 - val_loss: 2.5681
# Epoch 19/20
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9704 - loss: 0.0873 - val_accuracy: 0.6420 - val_loss: 2.5684
# Epoch 20/20
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9622 - loss: 0.1089 - val_accuracy: 0.6497 - val_loss: 2.7595

# %%
y_pred=model.predict(x_test_scaled)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
model.predict(x_test_scaled)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# array([[6.8532825e-07, 1.9254435e-11, 8.6971121e-03, ..., 1.1931206e-03,
#         8.7103331e-11, 1.8170365e-08],
#        [3.7841435e-11, 4.9537514e-18, 1.1097444e-14, ..., 5.4814704e-15,
#         9.9999940e-01, 5.3935361e-07],
#        [9.9931407e-01, 1.7156552e-08, 2.7169881e-05, ..., 8.9537550e-10,
#         6.1436411e-04, 8.8651523e-06],
#        ...,
#        [2.7470132e-13, 1.1198108e-14, 7.8596022e-17, ..., 2.3145796e-18,
#         1.0000000e+00, 9.2186810e-14],
#        [2.5181691e-19, 7.9280531e-15, 6.9048045e-05, ..., 4.5950951e-08,
#         3.4467832e-23, 3.4175858e-16],
#        [1.1996638e-04, 5.1632037e-07, 4.5257502e-07, ..., 1.4499335e-09,
#         5.8523035e-08, 2.5099324e-04]], dtype=float32)

# %%
from sklearn.metrics import confusion_matrix

# %%
from keras.layers import BatchNormalization
from keras.models import load_model,Model
from keras.applications.resnet50 import ResNet50
from keras import optimizers

# %%
conv_base=ResNet50(weights='imagenet',include_top=False,input_shape=(256,256,3))
